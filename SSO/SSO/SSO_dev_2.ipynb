# %%
import random as rndd
import math # cos() for Rastrigin
import copy # array-copying convenience
import sys	 # max float
import numpy as np

# %%
#-------fitness functions---------

# rastrigin function
def Rastrigin(position):
    fitness_value = 0.0
    for i in range(len(position)):
        xi = position[i]
        fitness_value += (xi * xi) - (10 * math.cos(2 * math.pi * xi)) + 10
    return fitness_value

#sphere function
def Sphere(position):
	fitness_value = 0.0
	for i in range(len(position)):
		xi = position[i]
		fitness_value += (xi*xi)
	return fitness_value
#-------------------------

def Ackley(axis):
    dim = len(axis)
    sum1 = 0
    sum2 = 0

    for x in axis:
        sum1 += x * x
        sum2 += math.cos(2 * math.pi * x)

    ans = -20 * math.exp(-0.2 * math.sqrt((1 / dim) * sum1)) - math.exp((1 / dim) * sum2) + 20 + math.exp(1)
    return ans

def Booth(x):  # Booth Function
    x1 = x[0]
    x2 = x[1]
    term1 = (x1 + 2*x2 - 7)**2
    term2 = (2*x1 + x2 - 5)**2
    return(term1 + term2)
#Z = (X + 2*Y - 7)**2 + (2*X + Y - 5)**2

def Beale(z):  # Beale Function
    x = z[0]
    y = z[1]
    term1 = (1.5 - x + x*y)**2
    term2 = (2.25 - x + x*y*y)**2
    term3 = (2.625 - x + x*y*y*y)**2
    return(term1 + term2)
#Z = (1.5 - X + X*Y)**2 + (2.25 - X + X*Y*Y)**2 + (2.625 - X + X*Y*Y*Y)**2

def Easom(z): #Easom Function
    x = z[0]
    y = z[1]
    term = (x - math.pi)**2 + (y - math.pi)**2
    return(-1*math.cos(x)*math.cos(y)*math.exp(-term))
#Z = -1*np.cos(X)*np.cos(Y)*np.exp(-((X - np.pi)**2 + (Y - np.pi)**2))

def Matyas(z): #Matyas Function
    x = z[0]
    y = z[1]
    term1 = 0.26*(x**2 + y**2)
    term2 = 0.48*x*y
    return(term1 - term2)
#Z = 0.26*(X**2 + Y**2) - 0.48*X*Y

def Himelblaus(z): #Himelblaus function
    x = z[0]
    y = z[1]
    term1 = (x**2 + y - 11)**2
    term2 = (x + y**2 - 7)**2
    return(term1 + term2)
#Z = (X**2 + Y - 11)**2 + (X + Y**2 - 7)**2

def Three_hump_camel(z): #Three hump-camel function
    x = z[0]
    y = z[1]
    return(2*x**2 - 1.05*x**4 + x*y + y**2 + (x**6)/6)
#Z = 2*X**2 - 1.05*X**4 + X*Y + Y**2 + (X**6)/6

def Schwefel(z): #schwefel function
    m = 0
    for i in range(len(z)):
        x = z[i]
        m = m + x*math.sin(math.sqrt(abs(x)))
    return((418.9829 * len(z)) - m)
#Z = 418.9829*d - X*np.sin(np.sqrt(abs(X))) - Y*np.sin(np.sqrt(abs(Y)))

def Schaffer(z): #Schaffer Function
    x = z[0]
    y = z[1]
    term1 = math.pow(math.sin(x**2 - y**2), 2) - 0.5
    term2 = (1 + 0.001*(x**2 + y**2))**2
    return(0.5 + term1/term2)

#Z = 0.5 + (math.pow(math.sin(x**2 - y**2), 2) - 0.5)/((1 + 0.001*(x**2 + y**2))**2)


def Griewank(z): # Griewank Function
    m = 0
    n = 1
    for i in range(0,len(z)):
        x = z[i]
        m = m + x**2
        n = n*math.cos(x/(math.sqrt(i+1)))

    return(m/4000 - n + 1)

def Rosenbrock(x):
    x = np.asarray(x)
    return np.sum(100.0*(x[1:]-x[:-1]**2.0)**2.0 + (1-x[:-1])**2.0,axis=0)

def Goldstein(z): #Goldstein price function
    x = z[0]
    y = z[1]
    fact1a = (x + y + 1)**2;
    fact1b = 19 - 14*x + 3*x**2 - 14*y + 6*x*y + 3*y**2;
    fact1 = 1 + fact1a*fact1b;

    fact2a = (2*x - 3*y)**2;
    fact2b = 18 - 32*x + 12*x**2 + 48*y - 36*x*y + 27*y**2;
    fact2 = 30 + fact2a*fact2b;
    return(fact1*fact2)

def Hartmann3(z): # Hartmann 3D Function
    alpha = [1.0, 1.2, 3.0, 3.2]
    A = [[3.0, 10, 30],[0.1, 10, 35],[3.0, 10, 30],[0.1, 10, 35]]
    P = [[3689*10**(-4), 1170*10**(-4), 2673*10**(-4)],[4699*10**(-4), 4387*10**(-4), 7470*10**(-4)],[1091*10**(-4), 8732*10**(-4), 5547*10**(-4)],[381*10**(-4), 5743*10**(-4), 8828*10**(-4)]]
    outer = 0;
    for i in range(4):
        inner = 0;
        for j in range(3):
            x = z[j]
            Aij = A[i][j]
            Pij = P[i][j]
            inner = inner + Aij*(x-Pij)**2
        new = alpha[i] * math.exp(-inner)
        outer = outer + new
    return(-outer)

def Hartmann6(z): # Hartmann 6D function
    alpha = [1.0, 1.2, 3.0, 3.2]
    A = [[10, 3, 17, 3.5, 1.7, 8],[0.05, 10, 17, 0.1, 8, 14],[3, 3.5, 1.7, 10, 17, 8],[17, 8, 0.05, 10, 0.1, 14]]
    P = [[1312*10**(-4), 1696*10**(-4), 5569*10**(-4), 124*10**(-4), 8283*10**(-4), 5886*10**(-4)],
               [2329*10**(-4), 4135*10**(-4), 8307*10**(-4), 3736*10**(-4), 1004*10**(-4), 9991*10**(-4)],
               [2348*10**(-4), 1451*10**(-4), 3522*10**(-4), 2883*10**(-4), 3047*10**(-4), 6650*10**(-4)],
               [4047*10**(-4), 8828*10**(-4), 8732*10**(-4), 5743*10**(-4), 1091*10**(-4), 381*10**(-4)]]

    outer = 0
    for i in range(4):
        inner = 0
        for j in range(6):
            x = z[j]
            Aij = A[i][j]
            Pij = P[i][j]
            inner = inner + Aij*(x-Pij)**2

        new = alpha[i] * math.exp(-inner)
        outer = outer + new
    return((-1*(2.58 + outer) )/ 1.94)

def Bent(z): #Bent Cigar function
    x = z[0]
    m = 0
    for i in range(1,len(z)):
        m = m + (z[i])**2
    return(x**2 + (10**6)*m)

def Zakharov(z): #Zakharov Function
    m = 0
    n = 0
    for i in range(len(z)):
        x = z[i]
        m = m + x**2
        n = n + 0.5*x

    return(m + n**2 + n**4)

def Levy(z): #Levy Function
    w = 1 + (z[0] - 1)/4
    k = 1 + (z[-1] - 1)/4
    t1 = math.cos(math.pi * z[0])**2
    t3 = ((k - 1)**2)*(1 + math.sin(2*math.pi*k))**2
    t2 = 0
    for i in range(len(z)-1):
        x = z[i]
        w = 1 + (x - 1)/4
        t2 = t2 + ((w - 1)**2)*(1 + 10 * math.sin((math.pi * x) + 1)**2)
    return(t1 + t2 + t3)

def High (z): #High Conditioned Ellipitical Function
    m = 0
    d = len(z)
    for i in range(len(z)):
        x = z[i]
        l = (i - 1)/(d - 1)
        m = m + (10**6)**(l) * (x**2)
    return(m)

def Discuss(z): #Discuss Function
    m = 0
    t1 = (10**6)*(z[0]**2)
    for i in range(1,len(z)):
        x = z[i]
        m = m + x**2
    return(t1 + m)

def Weierstrass(z): #Waistress Function
    m = 0
    a = 0.5
    b = 3
    k = 20
    d = len(z)
    for i in range(len(z)):
        x = z[i]
        n = 0
        for j in range(k):
            n = n + (a**k * math.cos((2 * math.pi* b**k)*(x + 0.5)))
        p = 0
        for j in range(k):
            p = p + (a**k * math.cos((2 * math.pi* b**k)*0.5))
        m = m + (n-(d*p))
    return(m)

# %%
# python implementation of particle swarm optimization (PSO)

#particle class
class Particle:
    def __init__(self, fitness, dim, minx, maxx, seed):
        self.rnd = rndd.Random(seed)

        # initialize position of the particle with 0.0 value
        self.position = [0.0 for i in range(dim)]

        # initialize velocity of the particle with 0.0 value
        self.velocity = [0.0 for i in range(dim)]

        # initialize best particle position of the particle with 0.0 value
        self.best_part_pos = [0.0 for i in range(dim)]

        # loop dim times to calculate random position and velocity
        # range of position and velocity is [minx, max]
        for i in range(dim):
            self.position[i] = ((maxx - minx) *
            self.rnd.random() + minx)
            self.velocity[i] = ((maxx - minx) *
            self.rnd.random() + minx)

        self.fitness = eval(fitness)(self.position)

        # initialize best position and fitness of this particle
        self.best_part_pos = copy.copy(self.position)
        self.best_part_fitnessVal = self.fitness # best fitness

# particle swarm optimization function
def pso(fitness, max_iter, n, dim, minx, maxx):
    # hyper parameters
    w = 0.729 # inertia
    c1 = 1.49445 # cognitive (particle)
    c2 = 1.49445 # social (swarm)

    rnd = rndd.Random(0)
    Conver = np.zeros(max_iter)
    # create n random particles
    swarm = [Particle(fitness, dim, minx, maxx, i) for i in range(n)]

    # compute the value of best_position and best_fitness in swarm
    best_swarm_pos = [0.0 for i in range(dim)]
    best_swarm_fitnessVal = sys.float_info.max # swarm best

    # computer best particle of swarm and it's fitness
    for i in range(n): # check each particle
        if swarm[i].fitness < best_swarm_fitnessVal:
            best_swarm_fitnessVal = swarm[i].fitness
            best_swarm_pos = copy.copy(swarm[i].position)

    # main loop of pso
    Iter = 0
    while Iter < max_iter:

        # after every 10 iterations
        # print iteration number and best fitness value so far
        #if Iter % 10 == 0 and Iter > 1:
            #print("Iter = " + str(Iter) + " best fitness = %.3f" % best_swarm_fitnessVal)

        for i in range(n): # process each particle

            # compute new velocity of curr particle
            for k in range(dim):
                r1 = rndd.random() # randomizations
                r2 = rndd.random()

                swarm[i].velocity[k] = (
                                        (w * swarm[i].velocity[k]) +
                                        (c1 * r1 * (swarm[i].best_part_pos[k] - swarm[i].position[k])) +
                                        (c2 * r2 * (best_swarm_pos[k] -swarm[i].position[k]))
                                    )


                # if velocity[k] is not in [minx, max]
                # then clip it
                if swarm[i].velocity[k] < minx:
                    swarm[i].velocity[k] = minx
                elif swarm[i].velocity[k] > maxx:
                    swarm[i].velocity[k] = maxx


        # compute new position using new velocity
        for k in range(dim):
            swarm[i].position[k] += swarm[i].velocity[k]

        swarm[i].fitness = eval(fitness)(swarm[i].position)

        # is new position a new best for the particle?
        if swarm[i].fitness < swarm[i].best_part_fitnessVal:
            swarm[i].best_part_fitnessVal = swarm[i].fitness
            swarm[i].best_part_pos = copy.copy(swarm[i].position)

        # is new position a new best overall?
        if swarm[i].fitness < best_swarm_fitnessVal:
            best_swarm_fitnessVal = swarm[i].fitness
            best_swarm_pos = copy.copy(swarm[i].position)

        # for-each particle
        Conver[Iter] = best_swarm_fitnessVal
        Iter += 1
    #end_while
    return best_swarm_fitnessVal, Conver
    # end pso

# %%
def SCA(SearchAgents_no, Max_iter, dim, lb, ub, objf):

    # destination_pos
    Dest_pos = np.zeros(dim)
    Dest_score = float("inf")

    if not isinstance(lb, list):
        lb = [lb] * dim
    if not isinstance(ub, list):
        ub = [ub] * dim

    # Initialize the positions of search agents
    Positions = np.zeros((SearchAgents_no, dim))
    for i in range(dim):
        Positions[:, i] = (
            np.random.uniform(0, 1, SearchAgents_no) * (ub[i] - lb[i]) + lb[i]
        )

    Convergence_curve = np.zeros(Max_iter)


    # Main loop
    for l in range(0, Max_iter):
        for i in range(0, SearchAgents_no):

            # Return back the search agents that go beyond the boundaries of the search space
            for j in range(dim):
                Positions[i, j] = np.clip(Positions[i, j], lb[j], ub[j])

            # Calculate objective function for each search agent
            fitness = eval(objf)(Positions[i,:])

            if fitness < Dest_score:
                Dest_score = fitness  # Update Dest_Score
                Dest_pos = Positions[i, :].copy()

        # Eq. (3.4)
        a = 2
        Max_iteration = Max_iter
        r1 = a - l * ((a) / Max_iteration)  # r1 decreases linearly from a to 0

        # Update the Position of search agents
        for i in range(0, SearchAgents_no):
            for j in range(0, dim):

                # Update r2, r3, and r4 for Eq. (3.3)
                r2 = (2 * np.pi) * rndd.random()
                r3 = 2 * rndd.random()
                r4 = rndd.random()

                # Eq. (3.3)
                if r4 < (0.5):
                    # Eq. (3.1)
                    Positions[i, j] = Positions[i, j] + (
                        r1 * np.sin(r2) * abs(r3 * Dest_pos[j] - Positions[i, j])
                    )
                else:
                    # Eq. (3.2)
                    Positions[i, j] = Positions[i, j] + (
                        r1 * np.cos(r2) * abs(r3 * Dest_pos[j] - Positions[i, j])
                    )

        Convergence_curve[l] = Dest_score



    return Dest_score, Convergence_curve

# %%
# wolf class
class wolf:
    def __init__(self, fitness, dim, minx, maxx, seed):
        self.rnd = rndd.Random(seed)
        self.position = [0.0 for i in range(dim)]

        for i in range(dim):
            self.position[i] = ((maxx - minx) * self.rnd.random() + minx)

        self.fitness = eval(fitness)(self.position) # curr fitness



# grey wolf optimization (GWO)
def gwo(fitness, max_iter, n, dim, minx, maxx):
	rnd = rndd.Random(0)

	# create n random wolves
	population = [ wolf(fitness, dim, minx, maxx, i) for i in range(n)]

	# On the basis of fitness values of wolves
	# sort the population in asc order
	population = sorted(population, key = lambda temp: temp.fitness)

	# best 3 solutions will be called as
	# alpha, beta and gaama
	alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])


	# main loop of gwo
	Iter = 0
	Conver = np.zeros(max_iter)
	while Iter < max_iter:

		# after every 10 iterations
		# print iteration number and best fitness value so far
		#if Iter % 10 == 0 and Iter > 1:
			#print("Iter = " + str(Iter) + " best fitness = %.3f" % alpha_wolf.fitness)

		# linearly decreased from 2 to 0
		a = 2*(1 - Iter/max_iter)

		# updating each population member with the help of best three members
		for i in range(n):
			A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
			2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
			C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()

			X1 = [0.0 for i in range(dim)]
			X2 = [0.0 for i in range(dim)]
			X3 = [0.0 for i in range(dim)]
			Xnew = [0.0 for i in range(dim)]
			for j in range(dim):
				X1[j] = alpha_wolf.position[j] - A1 * abs(
				C1 * alpha_wolf.position[j] - population[i].position[j])
				X2[j] = beta_wolf.position[j] - A2 * abs(
				C2 * beta_wolf.position[j] - population[i].position[j])
				X3[j] = gamma_wolf.position[j] - A3 * abs(
				C3 * gamma_wolf.position[j] - population[i].position[j])
				Xnew[j]+= X1[j] + X2[j] + X3[j]

			for j in range(dim):
				Xnew[j]/=3.0

			# fitness calculation of new solution
			fnew = eval(fitness)(Xnew)

			# greedy selection
			if fnew < population[i].fitness:
				population[i].position = Xnew
				population[i].fitness = fnew

		# On the basis of fitness values of wolves
		# sort the population in asc order
		population = sorted(population, key = lambda temp: temp.fitness)

		# best 3 solutions will be called as
		# alpha, beta and gaama
		alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])

		Conver[Iter] = alpha_wolf.fitness
		Iter+= 1

	# end-while

	# returning the best solution
	return eval(fitness)(alpha_wolf.position), Conver

#----------------------------

# %%
def roulette_wheel_selection(p):
  ''' Roulette Wheel Selection is a method of parent
  selection for breeding. We take the cummulative sum of probabilities
  and select the first parent whose cummulative sum is greater than
  random number'''

  c = np.cumsum(p)
  r = sum(p) * np.random.rand()
  ind = np.argwhere(r <= c)

  return ind[0][0]

def crossover(p1, p2):
  ''' Performing uniform crossover. Alpha is the flag
  that determines which gene of each chromosome is choosen
  to be inherited by the offspring. Maultiply the alpha value
  with each gene of every chromosome of both the parents and
  then add the resultant value to get child chromosome'''

  c1 = copy.deepcopy(p1)
  c2 = copy.deepcopy(p2)

  # Uniform crossover
  alpha = np.random.uniform(0, 1, *(c1['position'].shape))
  c1['position'] = alpha*p1['position'] + (1-alpha)*p2['position']
  c2['position'] = alpha*p2['position'] + (1-alpha)*p1['position']

  return c1, c2



def mutate(c, mu, sigma):
  '''
  c: child chromosome
  mu: mutation rate. % of gene to be modified
  sigma: step size of mutation'''

  y = copy.deepcopy(c)
  flag = np.random.rand(*(c['position'].shape)) <= mu  # array of True and Flase, indicating at which position to perform mutation
  ind = np.argwhere(flag)
  y['position'][ind] += sigma * np.random.randn(*ind.shape)

  return y



def bounds(c, varmin, varmax):
  ''' Defines the upper and lower bound of gene value'''

  c['position'] = np.maximum(c['position'], varmin)
  c['position'] = np.minimum(c['position'], varmax)



def sort(arr):
  ''' Bubble sorting the population + offsoring
  in every iteration to get best fit individuals at top'''

  n = len(arr)

  for i in range(n-1):

    for j in range(0, n-i-1):
            if arr[j]['cost'] > arr[j+1]['cost'] :
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

def ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, beta):

  # Placeholder for each individual
  population = {}
  for i in range(npop):                                                         # each inidivdual has position(chromosomes) and cost,
    population[i] = {'position': None, 'cost': None}                            # create individual as many as population size(npop)

  # Best solution found
  bestsol = copy.deepcopy(population)
  bestsol_cost = np.inf                                                         # initial best cost is infinity

  # Initialize population - 1st Gen
  for i in range(npop):
      population[i]['position'] = np.random.uniform(varmin, varmax, num_var)    # randomly initialize the chromosomes and cost
      population[i]['cost'] = eval(costfunc)(population[i]['position'])

      if population[i]['cost'] < bestsol_cost:                                  # if cost of an individual is less(best) than best cost,
        bestsol = copy.deepcopy(population[i])                                  # replace the best solution with that individual

  # Best cost of each generation/iteration
  bestcost = np.empty(maxit)

  # Main loop
  for it in range(maxit):

    # Calculating probability for roulette wheel selection
    costs = []
    for i in range(len(population)):
      costs.append(population[i]['cost'])                                       # list of all the population cost
    costs = np.array(costs)
    avg_cost = np.mean(costs)                                                   # taking average of the costs
    if avg_cost != 0:
      costs = costs/avg_cost
    probs = np.exp(-beta*costs)                                                 # probability is exponensial of -ve beta times costs

    for _ in range(num_children//2):                                            # we will be having two off springs for each crossover
                                                                                # hence divide number of children by 2
      '''
      -> choosing two parents randomly for mating
      -> we are shuffling all the 20 parent individuals and
      -> choosing first two of the shuffled array as our parents for mating

      Randomly selecting parents by shiffling them.
      But we will be using roulette wheel slection
      for our algorithm

      q = np.random.permutation(npop)
      p1 = population[q[0]]
      p2 = population[q[1]]
      '''

      # Roulette wheel selection
      p1 = population[roulette_wheel_selection(probs)]
      p2 = population[roulette_wheel_selection(probs)]

      # crossover two parents
      c1, c2 = crossover(p1, p2)

      # Perform mutation
      c1 = mutate(c1, mu, sigma)
      c2 = mutate(c2, mu, sigma)

      # Apply bounds
      bounds(c1, varmin, varmax)
      bounds(c2, varmin, varmax)

      # Evaluate first off spring
      c1['cost'] = eval(costfunc)(c1['position'])                                     # calculate cost function of child 1

      if type(bestsol_cost) == float:
        if c1['cost'] < bestsol_cost:                                           # replacing best solution in every generation/iteration
          bestsol_cost = copy.deepcopy(c1)
      else:
        if c1['cost'] < bestsol_cost['cost']:                                   # replacing best solution in every generation/iteration
          bestsol_cost = copy.deepcopy(c1)


      # Evaluate second off spring
      if c2['cost'] < bestsol_cost['cost']:                                     # replacing best solution in every generation/iteration
        bestsol_cost = copy.deepcopy(c2)

    # Merge, Sort and Select
    population[len(population)] = c1
    population[len(population)] = c2

    population = sort(population)

    # Store best cost
    bestcost[it] = bestsol_cost['cost']



  out = population
  Bestsol = bestsol_cost['cost']
  bestcost = bestcost
  return (Bestsol, bestcost)

beta = 1
prop_children = 1                                        # proportion of children to population
mu = 0.2                                                 # mutation rate 20%, 205 of 5 is 1, mutating 1 gene
sigma = 0.1                                              # step size of mutation

# %%
def Optimizer_prev(Max_iter, SearchAgents_no, dim, lb, ub, objf, Elite_agents, Inferior_agents):


    # initialize of Elite, Inferior
    Global_pos = np.zeros((1,dim))
    Global_score = np.ones(1)

    Elite_pos = np.zeros((Elite_agents ,dim))
    Elite_score = np.ones((Elite_agents ))

    Inferior_pos = np.zeros((Inferior_agents,dim))
    Inferior_score = np.ones((Inferior_agents))
    a_glob = np.ones((Max_iter,dim))

    if not isinstance(lb, list):
        lb = [lb] * dim
    if not isinstance(ub, list):
        ub = [ub] * dim

    # Initialize the positions of search agents
    Positions = np.zeros((SearchAgents_no, dim))
    Sorted_Positions = np.zeros((SearchAgents_no, dim))
    Convergence_curve = np.zeros(Max_iter)
    Fitness = np.ones((15))*np.inf
    Sorted_Fitness = np.ones((15))


    # initalization of search agents

    for i in range(0, SearchAgents_no):
        for j in range(dim):
            Positions[i, j] =(ub[j]-lb[j]) * rndd.random() + lb[j]

        # Calculate objective function for each search agent
        Fitness[i] = eval(objf)(Positions[i, :])


    #Sorting
    Sorted_Positions = sorted(Positions, key = eval(objf))
    Sorted_Fitness = sorted(Fitness)

    # Grouping
    Global_score = Sorted_Fitness[0]
    Global_pos = Sorted_Positions[0].copy()

    for i in range(0, Elite_agents):
                Elite_score[i] = Sorted_Fitness[i]
                Elite_pos[i] = Sorted_Positions[i].copy()


    for i in range(0, Inferior_agents):
        Inferior_score[i] = Sorted_Fitness[Elite_agents+i]
        Inferior_pos[i] = Sorted_Positions[Elite_agents+i].copy()

    for it in range (0, Max_iter):

        # Population Update
        a = 0.2*(1 - it/Max_iter)
        a_glob[it,:] = Elite_pos[1]
            #Elite
        for i in range(0, Elite_agents):
            u = []
            #print("Iter: ",it, "Agents_no: ",i,"Prev: ", Elite_pos[i], "Score: ",Elite_score[i])
            for j in range(dim):
                c1 = 1
                c2 = 1
                w = 0.7
                ra = rndd.random()
                rb = rndd.random()
                # Mean of the distribution
                Mean = Elite_pos[i,j]

                # satndard deviation of the distribution
                Standard_deviation = a

                # creating a normal distribution data
                values = np.random.normal(Mean, Standard_deviation, size = 100)
                intt = rndd.randint(0,99)
                ui = values[intt]

                Elite_pos[i,j] =  w*Elite_pos[i,j] + (c1*ra*(- Elite_pos[i,j] + ui)) + c2*rb*(Global_pos[j] - Elite_pos[i][j])

            Elite_score[i] = eval(objf)(Elite_pos[i, :])
            #print("Iter: ",it, "Agents_no: ",i,"New: ", Elite_pos[i], "Score: ",Elite_score[i])

             #Inferior
        for i in range(0, Inferior_agents):
                # Inferior position update

            for j in range(dim):


                Inferior_pos[i,j] = ((rndd.random()* (ub[j] - lb[j])) + lb[j] )

            Inferior_score[i] = eval(objf)(Inferior_pos[i, :])


        #Sorting
        Fitness =  np.concatenate((Elite_score, Inferior_score), axis = 0)
        Positions  =  np.concatenate((Elite_pos, Inferior_pos), axis = 0)

        Sorted_Positions = sorted(Positions, key = eval(objf))
        Sorted_Fitness = sorted(Fitness)

        if Sorted_Fitness[0] < Global_score :
            Global_score = Sorted_Fitness[0]
            Global_pos = Sorted_Positions[0].copy()
            #print("Global_Score", Global_score)

        for i in range(0, len(Elite_score)):
            Elite_score[i] = Sorted_Fitness[i]
            Elite_pos[i] = Sorted_Positions[i].copy()


        for i in range(0, len(Inferior_score)):
            Inferior_score[i] = Sorted_Fitness[Elite_agents+i]
            Inferior_pos[i] = Sorted_Positions[Elite_agents+i].copy()

        Convergence_curve[it] = Global_score


    return Global_score, Convergence_curve

# %%
def levy_flight(z, m, c):
    """
    Compute the probability distribution based on the given formula.
    
    Parameters:
        z (float): Value of z.
        m (float): Value of m.
        c (float): Constant c.

    Returns:
        float: Probability distribution result.
    """
    step = np.zeros(dim)
    for j in range(dim):
        step[j] = (m ** (z * (m - 1))) * min(z - m, c * z - m)
    return step

# def levy_flight(dim):
#     beta = 1.5  
#     sigma = (gamma(1 + beta) * np.sin(np.pi * beta / 2) / (gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)

#     u = np.random.normal(0, sigma, dim)
#     v = np.random.normal(0, 1, dim)

#     step = u / abs(v) ** (1 / beta)

#     return step



def Optimizer(Max_iter, SearchAgents_no, dim, lb, ub, objf, Elite_agents, Inferior_agents):

    # initialize of Sentinel, Elite, Inferior

    Sentinel_signal = 0

    Global_pos = np.zeros((1,dim))
    Global_score = np.ones(1)

    Elite_pos = np.zeros((Elite_agents,5,dim))
    Elite_score = np.ones((Elite_agents,5))

    Inferior_pos = np.zeros((Inferior_agents,5,dim))
    Inferior_score = np.ones((Inferior_agents,5))


    if not isinstance(lb, list):
        lb = [lb] * dim
    if not isinstance(ub, list):
        ub = [ub] * dim

    # Initialize the positions of search agents
    Positions = np.zeros((SearchAgents_no, dim))
    Convergence_curve = np.zeros(Max_iter)
    fitness = np.ones((15))
    

    for i in range(0, SearchAgents_no):
        for j in range(dim):
            Positions[i, j] =(ub[j]-lb[j]) * rndd.random() + lb[j]

        # Calculate objective function for each search agent
        fitness[i] = eval(objf)(Positions[i, :])

    #Sorting
    Positions = sorted(Positions, key = eval(objf))
    fitness.sort()

    Global_score = fitness[0]
    Global_pos = Positions[0].copy()

    for i in range(0, len(Elite_score)):
        Elite_score[i,0] = fitness[i]
        Elite_pos[i,0] = Positions[i].copy()

    for i in range(0, len(Inferior_score)):
        Inferior_score[i,0] = fitness[7+1]
        Inferior_pos[i,0] = Positions[7+1].copy()


    for it in range (0, Max_iter):

        a = 2*(1 - it/Max_iter)

        if it == 0 :
            lo = 1
        else :
            lo = 0

            # Population Update
        for comm in range (lo, 5):

            for i in range(0, len(Elite_score)):

                for j in range(dim):
                    # Gaussian  distribution with position at centre 
                    # E position update
                    z_value = 0.1
                    m_value = 0.1
                    c_value = 0.1
                    step = levy_flight(z_value, m_value, c_value)
                    Elite_pos[i,comm,j] = Positions[i][j] - rndd.random()*step[j]
                Elite_score[i,comm] = eval(objf)(Elite_pos[i,comm, :])

            for i in range(0, len(Inferior_score)):
                # Inferior position update

                for j in range(dim):

                    if rndd.random() > 0.5 :
                        Inferior_pos[i,comm,j] = (rndd.random()* (ub[j] - lb[j])) + lb[j]
                    else:

                        u =rndd.randint(0,14)
                        Inferior_pos[i,comm,j] = Inferior_pos[i,comm,j] + a*rndd.random()*(Inferior_pos[i,comm,j]- Inferior_pos[i,comm,j])

                Inferior_score[i,comm] = eval(objf)(Inferior_pos[i,comm, :])

                if Inferior_score[i,comm] < Global_score :

                    # Signal for regrouping
                    Sentinel_signal = 1
                    # Perform regrouping

                    # get min for every agent and sent that value to position and fitness

                    Int_score =  np.concatenate((Elite_score, Inferior_score), axis = 0)
                    Int_pos  =  np.concatenate((Elite_pos, Inferior_pos), axis = 0)
                    Bets = Int_score.min(axis = 1)

                    for i in range(0, SearchAgents_no):
                        array4 = list(Int_score[i])
                        t = array4.index(Bets[i])
                        fitness[i] = Int_score[i,t]
                        Positions[i] = Int_pos[i,t,:]

                    #Sorting
                    Positions = sorted(Positions, key = eval(objf)) # Personal Best
                    fitness.sort()

                    if fitness[0] < Global_score :

                        Global_score = fitness[0]
                        Global_pos = Positions[0].copy()

                    for i in range(0, len(Elite_score)):

                        Elite_score[i,0] = fitness[i]
                        Elite_pos[i,0] = Positions[i].copy()

                    for i in range(0, len(Inferior_score)):

                        Inferior_score[i,0] = fitness[7+i]
                        Inferior_pos[i,0] = Positions[7+i].copy()

        # Position Update after 5 iter of Elite
        for i in range(0, len(Elite_score)):

            for j in range(dim):
                c1 = 1.49445 # cognitive 
                c2= 1.49445 # social 
                r1 = rndd.random()    # randomizations
                r2 = rndd.random()
                # E position update toward global best
                Elite_pos[i,comm,j] = (  r1 * ( Positions[i][j]- Elite_pos[i][4][j])) + (  r2 * (Global_pos[j]-Elite_pos[i][4][j]))
            Elite_score[i,comm] = eval(objf)(Elite_pos[i,comm, :])

        #Sorting
        Int_score =  np.concatenate((Elite_score, Inferior_score), axis = 0)
        Int_pos  =  np.concatenate((Elite_pos, Inferior_pos), axis = 0)
        Bets = Int_score.min(axis = 1)

        for i in range(0, SearchAgents_no):
            array4 = list(Int_score[i])
            t = array4.index(Bets[i])
            fitness[i] = Int_score[i,t]
            Positions[i] = Int_pos[i,t,:]

        Positions = sorted(Positions, key = eval(objf))
        fitness.sort()

        if fitness[0] < Global_score :

            Global_score = fitness[0]
            Global_pos = Positions[0].copy()

        for i in range(0, len(Elite_score)):
            Elite_score[i,0] = fitness[i]
            Elite_pos[i,0] = Positions[i].copy()

        for i in range(0, len(Inferior_score)):
            Inferior_score[i,0] = fitness[7+i]
            Inferior_pos[i,0] = Positions[7+i].copy()

        Convergence_curve[it] = Global_score

    return Global_score, Convergence_curve

# %%
functions = {'Rastrigin': {'lb': -5.12, 'ub': 5.12, 'dim': 2},
        'Sphere': {'lb': -5.12, 'ub': 5.12, 'dim': 10},
        'Ackley': {'lb': -32.768, 'ub': 32.768, 'dim': 10},
        'Booth': {'lb': -10, 'ub': 10, 'dim': 2},
        'Beale': {'lb': -4.5, 'ub': 4.5, 'dim': 2},
        'Easom': {'lb': -100, 'ub': 100, 'dim': 2},
        'Matyas': {'lb': -10, 'ub': 10, 'dim': 2},
        'Himelblaus': {'lb': -6, 'ub': 6, 'dim': 2},
        'Three_hump_camel': {'lb': -5, 'ub': 5, 'dim': 2},
        'Schwefel': {'lb': -500, 'ub': 500, 'dim': 10},
        'Schaffer': {'lb': -100, 'ub': 100, 'dim': 2},
        'Griewank': {'lb': -600, 'ub': 600, 'dim': 2},
        'Rosenbrock': {'lb': -5, 'ub': 10, 'dim': 10},
        'Goldstein': {'lb': -2, 'ub': 2, 'dim': 2},
        'Hartmann3': {'lb': 0, 'ub': 1, 'dim': 3},
        'Hartmann6': {'lb': 0, 'ub': 1, 'dim': 6},
        'Bent': {'lb': -100, 'ub': 100, 'dim': 10},
        'Zakharov': {'lb': -5, 'ub': 10, 'dim': 10},
        'Levy': {'lb': -10, 'ub': 10, 'dim': 10},
        'High': {'lb': -100, 'ub': 100, 'dim': 10},
        'Discuss': {'lb': -100, 'ub': 100, 'dim': 10},
        'Weierstrass': {'lb': -100, 'ub': 100, 'dim': 10}
       }

# %%
# Driver code
num_particles = 15
num_children = int(np.round(prop_children * num_particles/2)*2)
max_iter = 500
best_sso_prev = np.ones((22,30))
Curve_sso_prev = np.zeros((22,30,max_iter))
best_ga = np.ones((22,30))
Curve_ga = np.zeros((22,30,max_iter))
best_pso = np.ones((22,30))
Curve_pso = np.zeros((22,30,max_iter))
best_gwo = np.ones((22,30))
Curve_gwo = np.zeros((22,30,max_iter))
best_sca = np.ones((22,30))
Curve_sca = np.zeros((22,30,max_iter))
best_sso = np.ones((22,30))
Curve_sso = np.zeros((22,30,max_iter))


Elite_agents = 7
Inferior_agents = num_particles - Elite_agents

func_dict = ['Rastrigin','Sphere', 'Ackley','Booth','Beale','Easom','Matyas','Himelblaus',
        'Three_hump_camel','Schwefel','Schaffer','Griewank','Rosenbrock','Goldstein',
        'Hartmann3','Hartmann6','Bent','Zakharov','Levy','High','Discuss','Weierstrass']

for i in range(0,22):
    for j in range(0,5):

        func = func_dict[i]
        lol = functions.get(func)
        lb = lol.get('lb')
        ub = lol.get('ub')
        dim = lol.get('dim')

        print(f"{func} function, dim = {dim}")

        best_ga[i,j],Curve_ga[i,j,:] = ga(func, dim, lb, ub, max_iter, num_particles, num_children, mu, sigma, beta)
        best_sso_prev[i,j], Curve_sso_prev[i,j,:] = Optimizer_prev(max_iter, num_particles, dim, lb, ub, func,  Elite_agents, Inferior_agents) # old SSO
        best_sso[i,j], Curve_sso[i,j,:] = Optimizer(max_iter, num_particles, dim, lb, ub, func,  Elite_agents, Inferior_agents) # New SSO
        best_sca[i,j], Curve_sca[i,j,:] = SCA(num_particles,max_iter, dim, lb, ub,func)
        best_pso[i,j], Curve_pso[i,j,:] = pso(func, max_iter, num_particles, dim, lb, ub)
        best_gwo[i,j], Curve_gwo[i,j,:] = gwo(func, max_iter, num_particles, dim, lb, ub)

        print("fitness of sso new = %.6f" % best_sso[i,j])
        print("fitness of sso prev = %.6f" % best_sso_prev[i,j])
        print("fitness of ga = %.6f" % best_ga[i,j])
        print("fitness of pso = %.6f" % best_pso[i,j])
        print("fitness of gwo = %.6f" % best_gwo[i,j])

        print()
# Out:
# Rastrigin function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000001
# fitness of ga = 0.016337
# fitness of pso = 8.959577
# fitness of gwo = 1.006804
#
# Rastrigin function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000001
# fitness of ga = 0.130131
# fitness of pso = 1.862225
# fitness of gwo = 1.006804
#
# Rastrigin function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.001154
# fitness of pso = 4.987934
# fitness of gwo = 1.006804
#
# Rastrigin function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000003
# fitness of ga = 1.152412
# fitness of pso = 9.949758
# fitness of gwo = 1.006804
#
# Rastrigin function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 1.046175
# fitness of pso = 9.955282
# fitness of gwo = 1.006804
#
# Sphere function, dim = 10
# fitness of sso new = 0.001878
# fitness of sso prev = 0.000001
# fitness of ga = 1.613907
# fitness of pso = 24.585352
# fitness of gwo = 0.000000
#
# Sphere function, dim = 10
# fitness of sso new = 0.003138
# fitness of sso prev = 0.000001
# fitness of ga = 3.849729
# fitness of pso = 42.477387
# fitness of gwo = 0.000000
#
# Sphere function, dim = 10
# fitness of sso new = 0.002437
# fitness of sso prev = 0.000001
# fitness of ga = 2.011006
# fitness of pso = 27.290357
# fitness of gwo = 0.000000
#
# Sphere function, dim = 10
# fitness of sso new = 0.000943
# fitness of sso prev = 0.000002
# fitness of ga = 4.523462
# fitness of pso = 48.591652
# fitness of gwo = 0.000000
#
# Sphere function, dim = 10
# fitness of sso new = 0.001730
# fitness of sso prev = 0.000001
# fitness of ga = 1.766102
# fitness of pso = 29.450141
# fitness of gwo = 0.000000
#
# Ackley function, dim = 10
# fitness of sso new = 0.071847
# fitness of sso prev = 0.001018
# fitness of ga = 10.711842
# fitness of pso = 18.322222
# fitness of gwo = 0.000000
#
# Ackley function, dim = 10
# fitness of sso new = 0.073174
# fitness of sso prev = 0.001346
# fitness of ga = 11.248875
# fitness of pso = 19.066655
# fitness of gwo = 0.000000
#
# Ackley function, dim = 10
# fitness of sso new = 0.081806
# fitness of sso prev = 0.001447
# fitness of ga = 11.915488
# fitness of pso = 19.238196
# fitness of gwo = 0.000000
#
# Ackley function, dim = 10
# fitness of sso new = 0.091519
# fitness of sso prev = 0.001416
# fitness of ga = 10.515543
# fitness of pso = 19.544134
# fitness of gwo = 0.000000
#
# Ackley function, dim = 10
# fitness of sso new = 0.092232
# fitness of sso prev = 0.001303
# fitness of ga = 11.462746
# fitness of pso = 18.457939
# fitness of gwo = 0.000000
#
# Booth function, dim = 2
# fitness of sso new = 0.004062
# fitness of sso prev = 0.002686
# fitness of ga = 0.004862
# fitness of pso = 0.551610
# fitness of gwo = 0.000000
#
# Booth function, dim = 2
# fitness of sso new = 0.000740
# fitness of sso prev = 0.055819
# fitness of ga = 0.000931
# fitness of pso = 0.911082
# fitness of gwo = 0.000000
#
# Booth function, dim = 2
# fitness of sso new = 0.000180
# fitness of sso prev = 0.010470
# fitness of ga = 0.027858
# fitness of pso = 0.011593
# fitness of gwo = 0.000000
#
# Booth function, dim = 2
# fitness of sso new = 0.000023
# fitness of sso prev = 0.047533
# fitness of ga = 0.151574
# fitness of pso = 3.422357
# fitness of gwo = 0.000000
#
# Booth function, dim = 2
# fitness of sso new = 0.001324
# fitness of sso prev = 0.049768
# fitness of ga = 0.092365
# fitness of pso = 0.000905
# fitness of gwo = 0.000000
#
# Beale function, dim = 2
# fitness of sso new = 0.000014
# fitness of sso prev = 0.001111
# fitness of ga = 0.001394
# fitness of pso = 0.209315
# fitness of gwo = 0.153516
#
# Beale function, dim = 2
# fitness of sso new = 0.000007
# fitness of sso prev = 0.000933
# fitness of ga = 0.072240
# fitness of pso = 0.214139
# fitness of gwo = 0.153516
#
# Beale function, dim = 2
# fitness of sso new = 0.000035
# fitness of sso prev = 0.000235
# fitness of ga = 0.263619
# fitness of pso = 0.231121
# fitness of gwo = 0.153516
#
# Beale function, dim = 2
# fitness of sso new = 0.000016
# fitness of sso prev = 0.002804
# fitness of ga = 0.002023
# fitness of pso = 0.228182
# fitness of gwo = 0.153516
#
# Beale function, dim = 2
# fitness of sso new = 0.000068
# fitness of sso prev = 0.009154
# fitness of ga = 0.001200
# fitness of pso = 0.227559
# fitness of gwo = 0.153516
#
# Easom function, dim = 2
# C:\Users\saxen\AppData\Local\Temp\ipykernel_16220\1367699771.py:101: RuntimeWarning: overflow encountered in exp
#   probs = np.exp(-beta*costs)                                                 # probability is exponensial of -ve beta times costs
# fitness of sso new = -0.999997
# fitness of sso prev = -0.992442
# fitness of ga = -0.862654
# fitness of pso = -0.000002
# fitness of gwo = -0.999997
#
# Easom function, dim = 2
# fitness of sso new = -0.999917
# fitness of sso prev = -0.979655
# fitness of ga = -0.539449
# fitness of pso = -0.000000
# fitness of gwo = -0.999997
#
# Easom function, dim = 2
# fitness of sso new = -0.999970
# fitness of sso prev = -0.967309
# fitness of ga = -0.487194
# fitness of pso = -0.000022
# fitness of gwo = -0.999997
#
# Easom function, dim = 2
# c:\ProgramData\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: RuntimeWarning: overflow encountered in accumulate
#   return bound(*args, **kwds)
# C:\Users\saxen\AppData\Local\Temp\ipykernel_16220\1367699771.py:8: RuntimeWarning: overflow encountered in double_scalars
#   r = sum(p) * np.random.rand()
# fitness of sso new = -0.999949
# fitness of sso prev = -0.972607
# fitness of ga = -0.000019
# fitness of pso = -0.000000
# fitness of gwo = -0.999997
#
# Easom function, dim = 2
# fitness of sso new = -0.999874
# fitness of sso prev = -0.983280
# fitness of ga = -0.099191
# fitness of pso = -0.000000
# fitness of gwo = -0.999997
#
# Matyas function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.007165
# fitness of pso = 0.071777
# fitness of gwo = 0.000000
#
# Matyas function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000138
# fitness of pso = 0.082560
# fitness of gwo = 0.000000
#
# Matyas function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000578
# fitness of pso = 0.083632
# fitness of gwo = 0.000000
#
# Matyas function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.003146
# fitness of pso = 0.010819
# fitness of gwo = 0.000000
#
# Matyas function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000054
# fitness of pso = 0.003008
# fitness of gwo = 0.000000
#
# Himelblaus function, dim = 2
# fitness of sso new = 0.000551
# fitness of sso prev = 0.129187
# fitness of ga = 0.004246
# fitness of pso = 13.120830
# fitness of gwo = 0.000000
#
# Himelblaus function, dim = 2
# fitness of sso new = 0.001478
# fitness of sso prev = 0.003068
# fitness of ga = 0.459079
# fitness of pso = 2.663181
# fitness of gwo = 0.000000
#
# Himelblaus function, dim = 2
# fitness of sso new = 0.000041
# fitness of sso prev = 0.053769
# fitness of ga = 0.106883
# fitness of pso = 0.028276
# fitness of gwo = 0.000000
#
# Himelblaus function, dim = 2
# fitness of sso new = 0.000545
# fitness of sso prev = 0.186718
# fitness of ga = 0.944755
# fitness of pso = 0.850774
# fitness of gwo = 0.000000
#
# Himelblaus function, dim = 2
# fitness of sso new = 0.000919
# fitness of sso prev = 0.183901
# fitness of ga = 0.085088
# fitness of pso = 8.411356
# fitness of gwo = 0.000000
#
# Three_hump_camel function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.007084
# fitness of pso = 0.304420
# fitness of gwo = 0.000000
#
# Three_hump_camel function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.002038
# fitness of pso = 0.379768
# fitness of gwo = 0.000000
#
# Three_hump_camel function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.001755
# fitness of pso = 0.314807
# fitness of gwo = 0.000000
#
# Three_hump_camel function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000149
# fitness of pso = 0.329983
# fitness of gwo = 0.000000
#
# Three_hump_camel function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000259
# fitness of pso = 0.591906
# fitness of gwo = 0.000000
#
# Schwefel function, dim = 10
# fitness of sso new = 1674.417489
# fitness of sso prev = 2016.473531
# fitness of ga = 2832.362445
# fitness of pso = 1888.366312
# fitness of gwo = -13352013750608562.000000
#
# Schwefel function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 2052.675539
# fitness of ga = 2803.309762
# fitness of pso = 1283.522230
# fitness of gwo = -13352013750608562.000000
#
# Schwefel function, dim = 10
# fitness of sso new = 671.827921
# fitness of sso prev = 1710.597151
# fitness of ga = 2570.601435
# fitness of pso = 2626.135625
# fitness of gwo = -13352013750608562.000000
#
# Schwefel function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 2374.374979
# fitness of ga = 2749.774680
# fitness of pso = 2117.687822
# fitness of gwo = -13352013750608562.000000
#
# Schwefel function, dim = 10
# fitness of sso new = 1596.905764
# fitness of sso prev = 2239.344568
# fitness of ga = 2568.555746
# fitness of pso = 2806.739562
# fitness of gwo = -13352013750608562.000000
#
# Schaffer function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.027790
# fitness of pso = 0.325966
# fitness of gwo = 0.000126
#
# Schaffer function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.022521
# fitness of pso = 0.432215
# fitness of gwo = 0.000126
#
# Schaffer function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.000541
# fitness of pso = 0.254416
# fitness of gwo = 0.000126
#
# Schaffer function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.001059
# fitness of pso = 0.354814
# fitness of gwo = 0.000126
#
# Schaffer function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.024349
# fitness of pso = 0.239955
# fitness of gwo = 0.000126
#
# Griewank function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.022761
# fitness of ga = 0.112962
# fitness of pso = 0.976609
# fitness of gwo = 0.007396
#
# Griewank function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.000000
# fitness of ga = 0.095028
# fitness of pso = 1.676583
# fitness of gwo = 0.007396
#
# Griewank function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.034864
# fitness of ga = 0.277788
# fitness of pso = 0.250300
# fitness of gwo = 0.007396
#
# Griewank function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.054379
# fitness of ga = 0.117975
# fitness of pso = 0.171961
# fitness of gwo = 0.007396
#
# Griewank function, dim = 2
# fitness of sso new = 0.000000
# fitness of sso prev = 0.067022
# fitness of ga = 0.047953
# fitness of pso = 0.615466
# fitness of gwo = 0.007396
#
# Rosenbrock function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 8.373153
# fitness of ga = 1232.366242
# fitness of pso = 48866.601151
# fitness of gwo = 8.948829
#
# Rosenbrock function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 8.760832
# fitness of ga = 3189.444845
# fitness of pso = 72410.277760
# fitness of gwo = 8.948829
#
# Rosenbrock function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 8.693554
# fitness of ga = 1708.983975
# fitness of pso = 115794.619687
# fitness of gwo = 8.948829
#
# Rosenbrock function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 8.693331
# fitness of ga = 1902.014126
# fitness of pso = 137506.191387
# fitness of gwo = 8.948829
#
# Rosenbrock function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 8.803475
# fitness of ga = 8280.737029
# fitness of pso = 89727.523873
# fitness of gwo = 8.948829
#
# Goldstein function, dim = 2
# fitness of sso new = 1.000000
# fitness of sso prev = 3.130742
# fitness of ga = 4.948897
# fitness of pso = 85.438298
# fitness of gwo = 3.000846
#
# Goldstein function, dim = 2
# fitness of sso new = 1.000000
# fitness of sso prev = 3.348308
# fitness of ga = 3.600874
# fitness of pso = 95.494277
# fitness of gwo = 3.000846
#
# Goldstein function, dim = 2
# fitness of sso new = 3.001238
# fitness of sso prev = 3.079768
# fitness of ga = 3.004329
# fitness of pso = 3.189520
# fitness of gwo = 3.000846
#
# Goldstein function, dim = 2
# fitness of sso new = 1.000000
# fitness of sso prev = 3.464528
# fitness of ga = 4.183565
# fitness of pso = 96.775036
# fitness of gwo = 3.000846
#
# Goldstein function, dim = 2
# fitness of sso new = 1.000000
# fitness of sso prev = 3.022639
# fitness of ga = 4.459539
# fitness of pso = 88.525820
# fitness of gwo = 3.000846
#
# Hartmann3 function, dim = 3
# fitness of sso new = -3.862411
# fitness of sso prev = -3.852437
# fitness of ga = -1.747510
# fitness of pso = -3.561563
# fitness of gwo = -3.839583
#
# Hartmann3 function, dim = 3
# fitness of sso new = -3.861718
# fitness of sso prev = -3.835557
# fitness of ga = -1.715483
# fitness of pso = -3.561563
# fitness of gwo = -3.839583
#
# Hartmann3 function, dim = 3
# fitness of sso new = -3.861252
# fitness of sso prev = -3.852381
# fitness of ga = -3.461296
# fitness of pso = -3.561563
# fitness of gwo = -3.839583
#
# Hartmann3 function, dim = 3
# fitness of sso new = -3.858434
# fitness of sso prev = -3.856738
# fitness of ga = -2.354533
# fitness of pso = -3.561563
# fitness of gwo = -3.839583
#
# Hartmann3 function, dim = 3
# fitness of sso new = -3.861767
# fitness of sso prev = -3.841762
# fitness of ga = -3.840088
# fitness of pso = -3.561563
# fitness of gwo = -3.839583
#
# Hartmann6 function, dim = 6
# fitness of sso new = -2.923620
# fitness of sso prev = -2.807802
# fitness of ga = -2.868163
# fitness of pso = -1.842618
# fitness of gwo = -2.883547
#
# Hartmann6 function, dim = 6
# fitness of sso new = -2.929057
# fitness of sso prev = -2.893325
# fitness of ga = -2.791132
# fitness of pso = -1.842618
# fitness of gwo = -2.883547
#
# Hartmann6 function, dim = 6
# fitness of sso new = -2.988742
# fitness of sso prev = -2.898557
# fitness of ga = -2.700116
# fitness of pso = -1.842618
# fitness of gwo = -2.883547
#
# Hartmann6 function, dim = 6
# fitness of sso new = -2.928525
# fitness of sso prev = -2.843450
# fitness of ga = -2.364883
# fitness of pso = -1.842618
# fitness of gwo = -2.883547
#
# Hartmann6 function, dim = 6
# fitness of sso new = -2.953561
# fitness of sso prev = -2.835047
# fitness of ga = -2.654021
# fitness of pso = -1.842618
# fitness of gwo = -2.883547
#
# Bent function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.758476
# fitness of ga = 1376502553.459792
# fitness of pso = 12978240496.405067
# fitness of gwo = 0.000000
#
# Bent function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.608304
# fitness of ga = 1310217865.975853
# fitness of pso = 10193116324.982164
# fitness of gwo = 0.000000
#
# Bent function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.375995
# fitness of ga = 716766032.406129
# fitness of pso = 5532241117.704833
# fitness of gwo = 0.000000
#
# Bent function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.827099
# fitness of ga = 1226050755.521927
# fitness of pso = 9554869574.670797
# fitness of gwo = 0.000000
#
# Bent function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 1.363498
# fitness of ga = 570960354.875150
# fitness of pso = 9268396213.768250
# fitness of gwo = 0.000000
#
# Zakharov function, dim = 10
# fitness of sso new = 0.003139
# fitness of sso prev = 0.000000
# fitness of ga = 44.429612
# fitness of pso = 116.632243
# fitness of gwo = 0.000000
#
# Zakharov function, dim = 10
# fitness of sso new = 0.002603
# fitness of sso prev = 0.000002
# fitness of ga = 165.907854
# fitness of pso = 109.182261
# fitness of gwo = 0.000000
#
# Zakharov function, dim = 10
# fitness of sso new = 0.001745
# fitness of sso prev = 0.000001
# fitness of ga = 70.182113
# fitness of pso = 95.531130
# fitness of gwo = 0.000000
#
# Zakharov function, dim = 10
# fitness of sso new = 0.002897
# fitness of sso prev = 0.000001
# fitness of ga = 52.808896
# fitness of pso = 37.611274
# fitness of gwo = 0.000000
#
# Zakharov function, dim = 10
# fitness of sso new = 0.002193
# fitness of sso prev = 0.000001
# fitness of ga = 8.129435
# fitness of pso = 92.787218
# fitness of gwo = 0.000000
#
# Levy function, dim = 10
# fitness of sso new = 0.081534
# fitness of sso prev = 1.441518
# fitness of ga = 2.432595
# fitness of pso = 47.429576
# fitness of gwo = 0.790797
#
# Levy function, dim = 10
# fitness of sso new = 0.138463
# fitness of sso prev = 1.802263
# fitness of ga = 3.957131
# fitness of pso = 45.756420
# fitness of gwo = 0.790797
#
# Levy function, dim = 10
# fitness of sso new = 0.169392
# fitness of sso prev = 1.052790
# fitness of ga = 6.239045
# fitness of pso = 28.876472
# fitness of gwo = 0.790797
#
# Levy function, dim = 10
# fitness of sso new = 0.079822
# fitness of sso prev = 2.079541
# fitness of ga = 2.879669
# fitness of pso = 39.219160
# fitness of gwo = 0.790797
#
# Levy function, dim = 10
# fitness of sso new = 0.128184
# fitness of sso prev = 1.869094
# fitness of ga = 0.354383
# fitness of pso = 45.280974
# fitness of gwo = 0.790797
#
# High function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.000302
# fitness of ga = 500987.125635
# fitness of pso = 59669835.816809
# fitness of gwo = 0.000000
#
# High function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.000976
# fitness of ga = 1110887.764416
# fitness of pso = 16076554.372274
# fitness of gwo = 0.000000
#
# High function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.004916
# fitness of ga = 22029015.702826
# fitness of pso = 35950899.670228
# fitness of gwo = 0.000000
#
# High function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.008206
# fitness of ga = 1080305.875157
# fitness of pso = 32842882.910888
# fitness of gwo = 0.000000
#
# High function, dim = 10
# fitness of sso new = 1.000000
# fitness of sso prev = 0.003185
# fitness of ga = 2705210.366576
# fitness of pso = 48946742.821391
# fitness of gwo = 0.000000
#
# Discuss function, dim = 10
# fitness of sso new = 0.023646
# fitness of sso prev = 0.000604
# fitness of ga = 5450.326682
# fitness of pso = 79459.248822
# fitness of gwo = 0.000000
#
# Discuss function, dim = 10
# fitness of sso new = 0.020054
# fitness of sso prev = 0.000225
# fitness of ga = 11392.218967
# fitness of pso = 25957.037356
# fitness of gwo = 0.000000
#
# Discuss function, dim = 10
# fitness of sso new = 0.018268
# fitness of sso prev = 0.000304
# fitness of ga = 5083.716539
# fitness of pso = 98157.663903
# fitness of gwo = 0.000000
#
# Discuss function, dim = 10
# fitness of sso new = 0.027649
# fitness of sso prev = 0.000476
# fitness of ga = 2513.040958
# fitness of pso = 30487.131113
# fitness of gwo = 0.000000
#
# Discuss function, dim = 10
# fitness of sso new = 0.039991
# fitness of sso prev = 0.000087
# fitness of ga = 7196.385613
# fitness of pso = 67284.167521
# fitness of gwo = 0.000000
#
# Weierstrass function, dim = 10
# fitness of sso new = 0.001722
# fitness of sso prev = 0.001759
# fitness of ga = 0.001756
# fitness of pso = 0.001756
# fitness of gwo = 0.001775
#
# Weierstrass function, dim = 10
# fitness of sso new = 0.001730
# fitness of sso prev = 0.001754
# fitness of ga = 0.001751
# fitness of pso = 0.001749
# fitness of gwo = 0.001775
#
# Weierstrass function, dim = 10
# fitness of sso new = 0.001726
# fitness of sso prev = 0.001759
# fitness of ga = 0.001762
# fitness of pso = 0.001760
# fitness of gwo = 0.001775
#
# Weierstrass function, dim = 10
# fitness of sso new = 0.001726
# fitness of sso prev = 0.001751
# fitness of ga = 0.001771
# fitness of pso = 0.001809
# fitness of gwo = 0.001775
#
# Weierstrass function, dim = 10
# fitness of sso new = 0.001755
# fitness of sso prev = 0.001769
# fitness of ga = 0.001749
# fitness of pso = 0.001753
# fitness of gwo = 0.001775

# %%
import statistics  as st
GWO_data = np.zeros((22,4))
PSO_data = np.zeros((22,4))
SSO_prev_data = np.zeros((22,4))
SSO_data = np.zeros((22,4))
GA_data = np.zeros((22,4))
SCA_data = np.zeros((22,4))

SSO_data[:,0] = [min(row) for row in best_sso]
SSO_data[:,1] = [max(row) for row in best_sso]
SSO_data[:,2] = [st.mean(row) for row in best_sso]
SSO_data[:,3] = [np.std(row) for row in best_sso]

SSO_prev_data[:,0] = [min(row) for row in best_sso_prev]
SSO_prev_data[:,1] = [max(row) for row in best_sso_prev]
SSO_prev_data[:,2] = [st.mean(row) for row in best_sso_prev]
SSO_prev_data[:,3] = [np.std(row) for row in best_sso_prev]


GWO_data[:,0] = [min(row) for row in best_gwo]
GWO_data[:,1] = [max(row) for row in best_gwo]
GWO_data[:,2] = [st.mean(row) for row in best_gwo]
GWO_data[:,3] = [np.std(row) for row in best_gwo]

PSO_data[:,0] = [min(row) for row in best_pso]
PSO_data[:,1] = [max(row) for row in best_pso]
PSO_data[:,2] = [st.mean(row) for row in best_pso]
PSO_data[:,3] = [np.std(row) for row in best_pso]

GA_data[:,0] = [min(row) for row in best_ga]
GA_data[:,1] = [max(row) for row in best_ga]
GA_data[:,2] = [st.mean(row) for row in best_ga]
GA_data[:,3] = [np.std(row) for row in best_ga]

SCA_data[:,0] = [min(row) for row in best_ga]
SCA_data[:,1] = [max(row) for row in best_ga]
SCA_data[:,2] = [st.mean(row) for row in best_ga]
SCA_data[:,3] = [np.std(row) for row in best_ga]

# %%
import pandas as pd

df1 = pd. DataFrame(SSO_data, columns=["SSO MIN", 'SSO MAX', "SSO MEAN", " SSO STD"])
df2 = pd. DataFrame(SSO_prev_data, columns=["SSO_prev MIN", 'SSO_prev MAX', "SSO_prev MEAN", "SSO_prev STD"])
df3 = pd. DataFrame(SCA_data, columns=["SCA MIN", ' SCA MAX', " SCA MEAN", "SCA STD"])
df4 = pd. DataFrame(PSO_data, columns=["PSO MIN", 'PSO MAX', "PSO MEAN", "PSO STD"])
df5 = pd. DataFrame(GA_data, columns=["GA MIN", 'GA MAX', "GA MEAN", "GA STD"])
df6 = pd. DataFrame(GWO_data, columns=[" GWO MIN", ' GWO MAX', " GWO MEAN", "GWO STD"] )

df = pd.concat([df1,df2,df3, df4, df5, df6], axis=1, join='inner')
print(df)
# Out:
#      SSO MIN      SSO MAX    SSO MEAN     SSO STD  SSO_prev MIN  SSO_prev MAX  \
# 0   0.000000     1.000000    0.833333    0.372678  1.445674e-07      1.000000
# 1   0.000943     1.000000    0.833671    0.371923  5.839626e-07      1.000000
# 2   0.071847     1.000000    0.847019    0.342094  1.017526e-03      1.000000
# 3   0.000023     1.000000    0.833544    0.372207  2.686285e-03      1.000000
# 4   0.000007     1.000000    0.833338    0.372668  2.354199e-04      1.000000
# 5  -0.999997     1.000000    0.666676    0.745334 -9.924422e-01      1.000000
# 6   0.000000     1.000000    0.833333    0.372678  1.756785e-12      1.000000
# 7   0.000041     1.000000    0.833451    0.372415  3.067517e-03      1.000000
# 8   0.000000     1.000000    0.833333    0.372678  1.771475e-10      1.000000
# 9   1.000000  1674.417489  132.338372  419.513939  1.000000e+00   2374.374979
# 10  0.000000     1.000000    0.833333    0.372678  1.687539e-14      1.000000
# 11  0.000000     1.000000    0.833333    0.372678  2.319138e-09      1.000000
# 12  1.000000     1.000000    1.000000    0.000000  1.000000e+00      8.803475
# 13  1.000000     3.001238    1.066708    0.359233  1.000000e+00      3.464528
# 14 -3.862411     1.000000    0.189814    1.811631 -3.856738e+00      1.000000
# 15 -2.988742     1.000000    0.342550    1.470137 -2.898557e+00      1.000000
# 16  1.000000     1.000000    1.000000    0.000000  3.759949e-01      1.363498
# 17  0.001745     1.000000    0.833753    0.371741  4.643045e-07      1.000000
# 18  0.079822     1.000000    0.853247    0.328452  1.000000e+00      2.079541
# 19  1.000000     1.000000    1.000000    0.000000  3.018413e-04      1.000000
# 20  0.018268     1.000000    0.837654    0.363031  8.734796e-05      1.000000
# 21  0.001722     1.000000    0.833622    0.372033  1.751426e-03      1.000000
#
#     SSO_prev MEAN  SSO_prev STD   SCA MIN       SCA MAX  ...      PSO MEAN  \
# 0        0.833334      0.372678  0.001154  1.152412e+00  ...  2.023826e+00
# 1        0.833333      0.372678  1.000000  4.523462e+00  ...  6.579830e+00
# 2        0.833551      0.372191  1.000000  1.191549e+01  ...  3.987638e+00
# 3        0.838876      0.360397  0.000931  1.000000e+00  ...  9.965849e-01
# 4        0.833808      0.371619  0.001200  1.000000e+00  ...  8.703438e-01
# 5        0.670157      0.737560 -0.862654  1.000000e+00  ...  8.333325e-01
# 6        0.833333      0.372678  0.000054  1.000000e+00  ...  8.417265e-01
# 7        0.851888      0.332509  0.004246  1.000000e+00  ...  1.669147e+00
# 8        0.833333      0.372678  0.000149  1.000000e+00  ...  8.973628e-01
# 9      347.282192    779.743184  1.000000  2.832362e+03  ...  3.582484e+02
# 10       0.833333      0.372678  0.000541  1.000000e+00  ...  8.869122e-01
# 11       0.839301      0.359463  0.047953  1.000000e+00  ...  9.563640e-01
# 12       2.277478      2.857200  1.000000  8.280737e+03  ...  1.547767e+04
# 13       1.368200      0.826194  1.000000  4.948897e+00  ...  1.314743e+01
# 14       0.192037      1.806662 -3.840088  1.000000e+00  ...  2.397395e-01
# 15       0.357394      1.436982 -2.868163  1.000000e+00  ...  5.262303e-01
# 16       0.964446      0.155483  1.000000  1.376503e+09  ...  1.584229e+09
# 17       0.833333      0.372678  1.000000  1.659079e+02  ...  1.589147e+01
# 18       1.108174      0.283492  0.354383  6.239045e+00  ...  7.718753e+00
# 19       0.833920      0.371369  1.000000  2.202902e+07  ...  6.449565e+06
# 20       0.833390      0.372552  1.000000  1.139222e+04  ...  1.004567e+04
# 21       0.833626      0.372023  0.001749  1.000000e+00  ...  8.336276e-01
#
#          PSO STD    GA MIN        GA MAX       GA MEAN        GA STD  \
# 0   2.638501e+00  0.001154  1.152412e+00  9.115403e-01  2.893997e-01
# 1   1.304884e+01  1.000000  4.523462e+00  1.292140e+00  8.157060e-01
# 2   6.683263e+00  1.000000  1.191549e+01  2.695150e+00  3.796120e+00
# 3   5.180593e-01  0.000931  1.000000e+00  8.425863e-01  3.527867e-01
# 4   2.899416e-01  0.001200  1.000000e+00  8.446825e-01  3.497649e-01
# 5   3.726798e-01 -0.862654  1.000000e+00  7.670498e-01  5.363895e-01
# 6   3.542120e-01  0.000054  1.000000e+00  8.337027e-01  3.718538e-01
# 7   2.530762e+00  0.004246  1.000000e+00  8.866684e-01  2.907791e-01
# 8   2.336265e-01  0.000149  1.000000e+00  8.337095e-01  3.718383e-01
# 9   8.290979e+02  1.000000  2.832362e+03  4.516535e+02  1.008759e+03
# 10  2.544841e-01  0.000541  1.000000e+00  8.358753e-01  3.670262e-01
# 11  2.447280e-01  0.047953  1.000000e+00  8.550568e-01  3.256536e-01
# 12  3.688352e+04  1.000000  8.280737e+03  5.446182e+02  1.611438e+03
# 13  3.080617e+01  1.000000  4.948897e+00  1.506574e+00  1.165914e+00
# 14  1.699994e+00 -3.840088  1.000000e+00  3.960363e-01  1.397164e+00
# 15  1.059381e+00 -2.868163  1.000000e+00  3.873895e-01  1.371639e+00
# 16  3.673533e+09  1.000000  1.376503e+09  1.733499e+08  4.104012e+08
# 17  3.517715e+01  1.000000  1.659079e+02  1.221526e+01  3.307991e+01
# 18  1.527874e+01  0.354383  6.239045e+00  1.362094e+00  1.129324e+00
# 19  1.563963e+07  1.000000  2.202902e+07  9.142144e+05  3.958847e+06
# 20  2.520028e+04  1.000000  1.139222e+04  1.055356e+03  2.645896e+03
# 21  3.720200e-01  0.001749  1.000000e+00  8.336263e-01  3.720230e-01
#
#           GWO MIN   GWO MAX      GWO MEAN       GWO STD
# 0    1.000000e+00  1.006804  1.001134e+00  2.535526e-03
# 1    2.302377e-79  1.000000  8.333333e-01  3.726780e-01
# 2    3.996803e-15  1.000000  8.333333e-01  3.726780e-01
# 3    1.604981e-08  1.000000  8.333333e-01  3.726780e-01
# 4    1.535159e-01  1.000000  8.589193e-01  3.154660e-01
# 5   -9.999967e-01  1.000000  6.666672e-01  7.453548e-01
# 6   3.310011e-209  1.000000  8.333333e-01  3.726780e-01
# 7    2.708714e-07  1.000000  8.333334e-01  3.726779e-01
# 8    7.378195e-58  1.000000  8.333333e-01  3.726780e-01
# 9   -1.335201e+16  1.000000 -2.225336e+15  4.976002e+15
# 10   1.258002e-04  1.000000  8.333543e-01  3.726311e-01
# 11   7.396176e-03  1.000000  8.345660e-01  3.699216e-01
# 12   1.000000e+00  8.948829  2.324805e+00  2.962354e+00
# 13   1.000000e+00  3.000846  1.333474e+00  7.456711e-01
# 14  -3.839583e+00  1.000000  1.934029e-01  1.803606e+00
# 15  -2.883547e+00  1.000000  3.527422e-01  1.447312e+00
# 16   1.252775e-62  1.000000  8.333333e-01  3.726780e-01
# 17   7.759163e-36  1.000000  8.333333e-01  3.726780e-01
# 18   7.907969e-01  1.000000  9.651328e-01  7.796540e-02
# 19   3.821101e-67  1.000000  8.333333e-01  3.726780e-01
# 20   2.133571e-67  1.000000  8.333333e-01  3.726780e-01
# 21   1.774619e-03  1.000000  8.336291e-01  3.720166e-01
#
# [22 rows x 24 columns]

# %%
# import dill
# filename = 'globalsave.pkl'
# dill.dump_session(filename)

# and to load the session again:
#dill.load_session(filename)

# %%
df.to_csv('Test.csv')

# %%
# import matplotlib.pyplot as plt
# 
# for t in range(0,22):
#     data_1 = best_ss[t,:]
#     data_2 = best_pso[t,:]
#     data_3 = best_ga[t,:]
#     data = [data_1, data_2, data_3]
#     fig = plt.figure(figsize =(10, 7))
# 
# # Creating axes instance
#     ax = fig.add_axes([0, 0, 1, 1])
# 
#     # x-axis labels
#     ax.set_xticklabels(['SSO', 'PSO',
#                     'GA'], fontsize = 14, fontweight = 'bold')
# 
# # Creating plot
#     bp = ax.boxplot(data)
# 
#     ax.tick_params(labelsize=14)
#     plt.ylabel("Fitnee Value",fontsize = 14,fontweight = 'bold' )
#     ax.get_xaxis().tick_bottom()
#     ax.get_yaxis().tick_left()
#     tt = func_dict[t]+".pdf"
#     plt.savefig(tt, format="pdf", bbox_inches="tight")
#     # show plot
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# X = np.arange(0,500)
# for t in range(0,22):
#     data_1 = Curve_ss[t,1,:]
#     data_2 = Curve_pso[t,1,:]
#     data_3 = Curve_ga[t,1,:]
#     fig, ax = plt.subplots(1, 1)
#     ax.figsize=(10, 7)
# 
# 
#     plt.plot(X,data_1, color='b', label='SSO')
#     plt.plot(X,data_2, color='r', label='PSO')
#     plt.plot(X,data_3, color='m', label='GA')
# 
#     ax.tick_params(labelsize=14)
#     plt.ylabel("Fitnee Value",fontsize = 14,fontweight = 'bold' )
#     plt.xlabel("Iteration",fontsize = 14, fontweight = 'bold' )
#     plt.legend()
#     tt = func_dict[t]+"cc.pdf"
#     plt.savefig(tt, format="pdf", bbox_inches="tight")
#     # show plot
#     plt.show()

# %%
# q,w,e = Optimizer(max_iter, num_particles, dim, lb, ub, func,  Elite_agents, Inferior_agents)

# %%
# X = np.arange(0,len(e),1)
# fig, ax = plt.subplots(1, 1)
# ax.figsize=(10, 5)
# plt.plot(X,e, color='m')
# 
# # Naming the x-axis, y-axis and the whole graph
# 
# plt.ylabel("Scaling Factor", fontsize = 14, fontweight = 'bold')
# plt.xlabel("Iterations", fontsize = 14, fontweight = 'bold')
# plt.legend()
# plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
# ax.tick_params(labelsize=14)
# plt.savefig("a.pdf", format="pdf", bbox_inches="tight")
# plt.show()
